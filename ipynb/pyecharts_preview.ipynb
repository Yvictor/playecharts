# %%
from pyecharts import online, configure
online()

# %%
configure(output_image='png')

# %%
from pyecharts import Bar

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 75, 90]
v2 = [10, 25, 8, 60, 20, 80]
bar = Bar("柱状图数据堆叠示例")
bar.add("商家A", attr, v1, is_stack=True)
bar.add("商家B", attr, v2, is_stack=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f8eeac2ea0244136b89b809cbfce2525" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f8eeac2ea0244136b89b809cbfce2525 = echarts.init(document.getElementById('f8eeac2ea0244136b89b809cbfce2525'), 'light', {renderer: 'canvas'});
#
# var option_f8eeac2ea0244136b89b809cbfce2525 = {
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
bar = Bar("标记线和标记点示例")
bar.add("商家A", attr, v1, mark_point=["average"])
bar.add("商家B", attr, v2, mark_line=["min", "max"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c6c82bb925fa4ef3b0be80ef60b5c70c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c6c82bb925fa4ef3b0be80ef60b5c70c = echarts.init(document.getElementById('c6c82bb925fa4ef3b0be80ef60b5c70c'), 'light', {renderer: 'canvas'});
#
# var option_c6c82bb925fa4ef3b0be80ef60b5c70c = {
#     "title": [
#         {
#             "text": "\u6807\u8bb0\u7ebf\u548c\u6807\u8bb0\u70b9\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
bar.print_echarts_options()
# Out:
# {
#     "title": [
#         {
#             "text": "\u6807\u8bb0\u7ebf\u548c\u6807\u8bb0\u70b9\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3304371,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
# ...

# %%
bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, v2)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="95fe457acef848598e8d469ba63a8dbd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_95fe457acef848598e8d469ba63a8dbd = echarts.init(document.getElementById('95fe457acef848598e8d469ba63a8dbd'), 'light', {renderer: 'canvas'});
#
# var option_95fe457acef848598e8d469ba63a8dbd = {
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1,)
bar.add("商家B", attr, v2, is_convert=True)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="685e6cbb5eee46939526da30d01d6a90" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_685e6cbb5eee46939526da30d01d6a90 = echarts.init(document.getElementById('685e6cbb5eee46939526da30d01d6a90'), 'light', {renderer: 'canvas'});
#
# var option_685e6cbb5eee46939526da30d01d6a90 = {
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
from pyecharts import EffectScatter

es = EffectScatter("动态散点图各种图形示例")
es.add("", [10], [10], symbol_size=20, effect_scale=3.5, effect_period=3, symbol="pin")
es.add("", [20], [20], symbol_size=12, effect_scale=4.5, effect_period=4,symbol="rect")
es.add("", [30], [30], symbol_size=30, effect_scale=5.5, effect_period=5,symbol="roundRect")
es.add("", [40], [40], symbol_size=10, effect_scale=6.5, effect_brushtype='fill',symbol="diamond")
es.add("", [50], [50], symbol_size=16, effect_scale=5.5, effect_period=5,symbol="arrow")
es.add("", [60], [60], symbol_size=6, effect_scale=2.5, effect_period=3,symbol="triangle")

es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c5dbbd8027e14e29bafe0e36fb06c3fb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c5dbbd8027e14e29bafe0e36fb06c3fb = echarts.init(document.getElementById('c5dbbd8027e14e29bafe0e36fb06c3fb'), 'light', {renderer: 'canvas'});
#
# var option_c5dbbd8027e14e29bafe0e36fb06c3fb = {
#     "title": [
#         {
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u5404\u79cd\u56fe\u5f62\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...

# %%
from pyecharts import Funnel

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
value = [20, 40, 60, 80, 100, 120]
funnel = Funnel("漏斗图示例")
funnel.add("商品", attr, value, is_label_show=True, label_pos="inside", label_text_color="#fff")

funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6b5ec278e130483091a090dc498de3d3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6b5ec278e130483091a090dc498de3d3 = echarts.init(document.getElementById('6b5ec278e130483091a090dc498de3d3'), 'light', {renderer: 'canvas'});
#
# var option_6b5ec278e130483091a090dc498de3d3 = {
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
from pyecharts import Gauge

gauge = Gauge("仪表盘示例")
gauge.add("业务指标", "完成率", 66.66)

gauge
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bd68b639563a402dbf1ba6ed61d0aa62" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bd68b639563a402dbf1ba6ed61d0aa62 = echarts.init(document.getElementById('bd68b639563a402dbf1ba6ed61d0aa62'), 'light', {renderer: 'canvas'});
#
# var option_bd68b639563a402dbf1ba6ed61d0aa62 = {
#     "title": [
#         {
#             "text": "\u4eea\u8868\u76d8\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
gauge._option['series'][0]['data'][0]['value'] = 0
display(gauge)
clear_output()

# %%
for i in range(101):
    gauge._option['series'][0]['data'][0]['value'] = i
    display(gauge)
    clear_output()
    time.sleep(0.05)

# %%
import time
from IPython.display import display, clear_output

# %%
gauge.options['series'] = [gauge.options['series'][0]]

# %%
type(gauge.options)
# Out:
# dict

# %%
gauge.options['series'][0]['data'][0]['value'] = 10

# %%
gauge.options['series'][0]['data'][0]
# Out:
# {'value': 66.66, 'name': '完成率'}

# %%
gauge._option['series'][0]['data'][0]['value'] = 10

# %%
gauge._option['series'] #= [gauge._option['series'][0]]
# Out:
# [{'type': 'gauge',
#   'detail': {'formatter': '{value}%'},
#   'name': '业务指标',
#   'min': 0,
#   'max': 100,
#   'startAngle': 225,
#   'endAngle': -45,
#   'data': [{'value': 66.66, 'name': '完成率'}]}]

# %%
gauge._option['series']
# Out:
# [{'type': 'gauge',
#   'detail': {'formatter': '{value}%'},
#   'name': '业务指标',
#   'min': 0,
#   'max': 100,
#   'startAngle': 225,
#   'endAngle': -45,
#   'data': [{'value': 10, 'name': '完成率'}]},
#  {'type': 'gauge',
#   'detail': {'formatter': '{value}%'},
#   'name': '业务指标',
#   'min': 0,
#   'max': 100,
#   'startAngle': 225,
#   'endAngle': -45,
#   'data': [{'value': 66.66, 'name': '完成率'}]}]

# %%
gauge._option['series']
# Out:
# [{'type': 'gauge',
#   'detail': {'formatter': '{value}%'},
#   'name': '业务指标',
#   'min': 0,
#   'max': 100,
#   'startAngle': 225,
#   'endAngle': -45,
#   'data': [{'value': 10, 'name': '完成率'}]}]

# %%
gauge._option['series'][0]
# Out:
# {'type': 'gauge',
#  'detail': {'formatter': '{value}%'},
#  'name': '业务指标',
#  'min': 0,
#  'max': 100,
#  'startAngle': 225,
#  'endAngle': -45,
#  'data': [{'value': 10, 'name': '完成率'}]}

# %%
gauge.options['series'][0]['data'][0]
# Out:
# {'value': 10, 'name': '完成率'}

# %%
gauge.__repr__??

# %%
import datetime as dt

# %%
from pyecharts import Kline

v1 = [[2320.26, 2320.26, 2287.3, 2362.94], [2300, 2291.3, 2288.26, 2308.38],
      [2295.35, 2346.5, 2295.35, 2345.92], [2347.22, 2358.98, 2337.35, 2363.8],
      [2360.75, 2382.48, 2347.89, 2383.76], [2383.43, 2385.42, 2371.23, 2391.82],
      [2377.41, 2419.02, 2369.57, 2421.15], [2425.92, 2428.15, 2417.58, 2440.38],
      [2411, 2433.13, 2403.3, 2437.42], [2432.68, 2334.48, 2427.7, 2441.73],
      [2430.69, 2418.53, 2394.22, 2433.89], [2416.62, 2432.4, 2414.4, 2443.03],
      [2441.91, 2421.56, 2418.43, 2444.8], [2420.26, 2382.91, 2373.53, 2427.07],
      [2383.49, 2397.18, 2370.61, 2397.94], [2378.82, 2325.95, 2309.17, 2378.82],
      [2322.94, 2314.16, 2308.76, 2330.88], [2320.62, 2325.82, 2315.01, 2338.78],
      [2313.74, 2293.34, 2289.89, 2340.71], [2297.77, 2313.22, 2292.03, 2324.63],
      [2322.32, 2365.59, 2308.92, 2366.16], [2364.54, 2359.51, 2330.86, 2369.65],
      [2332.08, 2273.4, 2259.25, 2333.54], [2274.81, 2326.31, 2270.1, 2328.14],
      [2333.61, 2347.18, 2321.6, 2351.44], [2340.44, 2324.29, 2304.27, 2352.02],
      [2326.42, 2318.61, 2314.59, 2333.67], [2314.68, 2310.59, 2296.58, 2320.96],
      [2309.16, 2286.6, 2264.83, 2333.29], [2282.17, 2263.97, 2253.25, 2286.33],
      [2255.77, 2270.28, 2253.31, 2276.22]]
kline = Kline("K 线图示例")
kline.add("日K", ["2017/7/{}".format(i + 1) for i in range(31)], v1)

kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="747309d2b4fb44e5855f7cc01e18ff24" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_747309d2b4fb44e5855f7cc01e18ff24 = echarts.init(document.getElementById('747309d2b4fb44e5855f7cc01e18ff24'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_747309d2b4fb44e5855f7cc01e18ff24 = {
#     "title": [
#         {
#             "text": "K \u7ebf\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
# ...

# %%
kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="747309d2b4fb44e5855f7cc01e18ff24" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_747309d2b4fb44e5855f7cc01e18ff24 = echarts.init(document.getElementById('747309d2b4fb44e5855f7cc01e18ff24'), 'light', {renderer: 'canvas'});
# function kline_tooltip_formatter(params) {
#     var text;
#     text = ((((((((((((params[0].seriesName + "<br/>") + "- open:") + params[0].data[1]) + "<br/>") + "- close:") + params[0].data[2]) + "<br/>") + "- lowest:") + params[0].data[3]) + "<br/>") + "- highest:") + params[0].data[4]);
#     return text;
# }
#
# var option_747309d2b4fb44e5855f7cc01e18ff24 = {
#     "title": [
#         {
#             "text": "K \u7ebf\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
# ...

# %%
kline._Kline__add??

# %%
i = -1
kline._option['series'][0]['data'][i]
# Out:
# [2255.77, 2270.28, 2253.31, 2276.22]

# %%
kline._option['series'][0]['data'].append(kline._option['series'][0]['data'][i])

# %%
["2017/7/{}".format(i + 1) for i in range(31)]
# Out:
# ['2017/7/1',
#  '2017/7/2',
#  '2017/7/3',
#  '2017/7/4',
#  '2017/7/5',
#  '2017/7/6',
#  '2017/7/7',
#  '2017/7/8',
#  '2017/7/9',
#  '2017/7/10',
#  '2017/7/11',
#  '2017/7/12',
#  '2017/7/13',
#  '2017/7/14',
#  '2017/7/15',
#  '2017/7/16',
#  '2017/7/17',
#  '2017/7/18',
#  '2017/7/19',
#  '2017/7/20',
#  '2017/7/21',
#  '2017/7/22',
#  '2017/7/23',
#  '2017/7/24',
#  '2017/7/25',
#  '2017/7/26',
#  '2017/7/27',
#  '2017/7/28',
#  '2017/7/29',
#  '2017/7/30',
#  '2017/7/31']

# %%
d = dt.date(2017, 7, 1)
d.strftime('%Y/%m/%d')
# Out:
# '2017/07/01'

# %%
xaxis = kline._get_all_options(x_axis=[(dt.date(2017, 7, 1) + dt.timedelta(days=i)).strftime('%Y/%m/%d') 
                               for i in range(32)])["xy_axis"][0]

# %%
kline._option.update(xAxis=xaxis)

# %%
xaxis = kline._option['xAxis'][0]

# %%
xaxis.config
# Out:
# {'show': True,
#  'nameLocation': 'middle',
#  'nameGap': 25,
#  'nameTextStyle': {'fontSize': 14},
#  'axisTick': {'alignWithLabel': False},
#  'inverse': False,
#  'boundaryGap': True,
#  'type': 'category',
#  'splitLine': {'show': False},
#  'axisLine': {'lineStyle': {'width': 1}},
#  'axisLabel': <pyecharts.echarts.axis.XAxisLabel at 0x7fdf30b7ed68>,
#  'data': ['2017/7/1',
#   '2017/7/2',
#   '2017/7/3',
#   '2017/7/4',
#   '2017/7/5',
#   '2017/7/6',
#   '2017/7/7',
#   '2017/7/8',
#   '2017/7/9',
#   '2017/7/10',
#   '2017/7/11',
#   '2017/7/12',
#   '2017/7/13',
#   '2017/7/14',
#   '2017/7/15',
#   '2017/7/16',
#   '2017/7/17',
#   '2017/7/18',
#   '2017/7/19',
#   '2017/7/20',
#   '2017/7/21',
#   '2017/7/22',
#   '2017/7/23',
#   '2017/7/24',
#   '2017/7/25',
#   '2017/7/26',
#   '2017/7/27',
#   '2017/7/28',
#   '2017/7/29',
#   '2017/7/30',
#   '2017/7/31'],
#  'scale': True}
